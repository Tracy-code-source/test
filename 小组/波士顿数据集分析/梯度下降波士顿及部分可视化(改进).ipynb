# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
Boston_data = pd.read_csv(r'C:\Users\HUANG\Downloads\house_data.csv')
col = Boston_data.columns
col
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
plt.scatter(Boston_data['RM'], Boston_data['MEDV']) # 看似正相关

# %%
X = Boston_data.iloc[:, 0: 13].values
X = np.insert(X, 0, values = 1, axis = 1)
y = Boston_data.iloc[:, -1].values
w = np.zeros(X.shape[1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 888)
alpha = 0.000001
ite = 1000000

# %%
def gradient_descent(X, y, w, alpha, ite):
    cost_remain = [] # 记录损失均方误差
    num = X.shape[0]
    for i in range (0, ite, 1):
        Loss = np.dot(X, w) - y
        cost = np.sum(Loss ** 2) / (num * 2)
        cost_remain.append(cost)
        dw = (1 / num) * np.dot(X.T, Loss)
        w -= alpha * dw

    return w, cost_remain

# %%
final_w, remain = gradient_descent(X_train, y_train, w, alpha, ite)

# %%
X_part = [X_test[0][6], X_test[101][6]]
y_part = [y_test_forecast[0], y_test_forecast[101]]

# %%
y_test_forecast = np.dot(X_test, final_w)
plt.scatter(X_test[:, 6], y_test)
plt.plot(X_part, y_part, color = 'red')

# %%
#remain

# %%
X_test.shape
# Out:
# (102, 14)

# %%
y_test
# Out:
# array([22.4, 32.4, 21.7, 24.5, 16.8, 21.1, 29.4, 28.7, 21.5, 13.6, 21.4,
#        24.8, 16.8, 19.4, 21.7, 17.2, 17.1, 18.7, 22.3, 25. , 24.4, 34.6,
#        20.1, 22.3, 26.7, 15.6, 19.5, 14.3, 22.7, 21.6, 25. , 24.7, 17.8,
#        12.7, 22.7, 46.7, 20.2, 27.1, 25. , 19.9, 32. , 23.2, 32.2, 19.2,
#        21. , 13.4, 31.6, 16.7,  7. , 24.5, 24.2, 11.5, 10.9, 22. , 15.7,
#        25.3, 14.9, 15. , 33.4, 28.7, 50. , 25. , 29.9, 26.6, 28.7, 20.5,
#        23. , 37. , 30.3, 16.2, 22.2, 19.9, 36. , 48.5, 26.4, 19.8, 17.8,
#        38.7, 11.7, 13.8, 15.2, 30.1,  8.1, 30.1, 24. , 17.8, 13.8,  7.5,
#        41.3, 20.1, 13.9, 50. , 20.3, 22.6, 25. , 20.5, 12.8, 19.5, 22. ,
#        19.1, 24.6, 50. ])

# %%
y_test.shape
# Out:
# (102,)
